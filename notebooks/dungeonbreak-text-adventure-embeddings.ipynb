# %% [markdown]
# # DungeonBreak Text Adventure (Embeddings) - Escape the Dungeon
#
# Compatibility notebook: this demo now uses the modular **Escape the Dungeon** engine.

# %%
import sys
from pathlib import Path

for base in [Path.cwd(), Path.cwd().parent]:
    if (base / 'src' / 'dungeonbreak_narrative').exists():
        sys.path.insert(0, str(base))
        break

from dungeonbreak_narrative import create_session, create_notebook_widget

# %%
session = create_session(player_name='Kael', prefer_sentence_transformer=False)
game = session.game
print(game.look())
print('status:', game.status())

# %%
create_notebook_widget(game)
